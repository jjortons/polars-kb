# %%
# !pip install ipython-sql
# !pip install psycopg2-binary

# %%
import pandas as pd
import os

# %load_ext sql

# %env host= localhost
host= os.environ.get('host')
pw  = os.environ.get('PSQL_PW')
#print(host)

# shld be DATABASE_URL or else will get 
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
# %env DATABASE_URL=postgresql://postgres:{pw}@{host}:5432/Adventureworks

# %sql postgresql://postgres:{pw}@{host}:5432/Adventureworks
# Out:
# env: host=localhost

# %%
# %%sql
# select * from sales.salesorderheader s limit 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/Adventureworks
# 5 rows affected.
# [(43660, 8, datetime.datetime(2011, 5, 31, 0, 0), datetime.datetime(2011, 6, 12, 0, 0), datetime.datetime(2011, 6, 7, 0, 0), 5, False, 'PO18850127500', '10-4020-000117', 29672, 279, 5, 921, 921, 5, 5618, '115213Vi29411', None, Decimal('1294.2529'), Decimal('124.2483'), Decimal('38.8276'), Decimal('1457.3288'), None, UUID('738dc42d-d03b-48a1-9822-f95a67ea7389'), datetime.datetime(2011, 6, 7, 0, 0)),
#  (43661, 8, datetime.datetime(2011, 5, 31, 0, 0), datetime.datetime(2011, 6, 12, 0, 0), datetime.datetime(2011, 6, 7, 0, 0), 5, False, 'PO18473189620', '10-4020-000442', 29734, 282, 6, 517, 517, 5, 1346, '85274Vi6854', 4, Decimal('32726.4786'), Decimal('3153.7696'), Decimal('985.553'), Decimal('36865.8012'), None, UUID('d91b9131-18a4-4a11-bc3a-90b6f53e9d74'), datetime.datetime(2011, 6, 7, 0, 0)),
# ...

# %%
# %%sql
# select * from sales.salesorderdetail
# where carriertrackingnumber like '491%C%'
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/Adventureworks
# 12 rows affected.
# [(43659, 1, '4911-403C-98', 1, 776, 1, Decimal('2024.994'), Decimal('0'), UUID('b207c96d-d9e6-402b-8470-2cc176c42283'), datetime.datetime(2011, 5, 31, 0, 0)),
#  (43659, 2, '4911-403C-98', 3, 777, 1, Decimal('2024.994'), Decimal('0'), UUID('7abb600d-1e77-41be-9fe5-b9142cfc08fa'), datetime.datetime(2011, 5, 31, 0, 0)),
#  (43659, 3, '4911-403C-98', 1, 778, 1, Decimal('2024.994'), Decimal('0'), UUID('475cf8c6-49f6-486e-b0ad-afc6a50cdd2f'), datetime.datetime(2011, 5, 31, 0, 0)),
#  (43659, 4, '4911-403C-98', 1, 771, 1, Decimal('2039.994'), Decimal('0'), UUID('04c4de91-5815-45d6-8670-f462719fbce3'), datetime.datetime(2011, 5, 31, 0, 0)),
#  (43659, 5, '4911-403C-98', 1, 772, 1, Decimal('2039.994'), Decimal('0'), UUID('5a74c7d2-e641-438e-a7ac-37bf23280301'), datetime.datetime(2011, 5, 31, 0, 0)),
# ...
