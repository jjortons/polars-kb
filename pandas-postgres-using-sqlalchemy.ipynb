# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

import getpass

# set formats
#pd.options.display.float_format = '${:,.2f}'.format # affects entire session
pd.options.display.float_format = '{:,.2f}'.format # affects entire session 

# prompt for postgres password
pw = getpass.getpass(prompt= 'Enter password to local postgresql database: ', stream= None)

# connect to northwind db from jupyter nb
conn = 'postgresql+psycopg2://postgres:'+ pw + '@localhost:5432/Adventureworks'

ae = create_engine(conn, pool_recycle= 3600);
#print(conn, ae)

# test conn
#df= pd.read_sql("select * from production.billofmaterials", ae)
df= pd.read_sql("select * from sales.salesorderdetail", ae)

df.head()
# Out:
# Enter password to local postgresql database:  ········
#    salesorderid  salesorderdetailid carriertrackingnumber  orderqty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
# 2         43659                   3          4911-403C-98         1
# 3         43659                   4          4911-403C-98         1
# 4         43659                   5          4911-403C-98         1
#
#    productid  specialofferid  unitprice  unitpricediscount  \
# 0        776               1   2,024.99               0.00
# 1        777               1   2,024.99               0.00
# 2        778               1   2,024.99               0.00
# 3        771               1   2,039.99               0.00
# 4        772               1   2,039.99               0.00
#
#                                 rowguid modifieddate
# 0  b207c96d-d9e6-402b-8470-2cc176c42283   2011-05-31
# ...
